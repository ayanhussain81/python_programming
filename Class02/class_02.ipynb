# %%
print("hello")
# Out:
# hello

# %%
a =23
print(a)
# Out:
# 23

# %%
print(6*2)
# Out:
# 12

# %% [markdown]
# Data Types

# %%
# String "Ayan", "Karachi"
# int 12,3,4,5, -5
# float 0.12 43.50, 80.25
# boolean True/false

# %%
class_variable = 8 # int
print(class_variable)
# Out:
# 8

# %%
print(type(class_variable))
# Out:
# <class 'int'>

# %%
a = 10
b = 20 
check = a > b
print(check)
# Out:
# False

# %%
age = "15" # str
age_2 =15 #int
age_3 = 15.25 #float
print(type(age), age)
print(type(age_2),age_2)
print(type(age_3),age_3)
# Out:
# <class 'str'> 15
# <class 'int'> 15
# <class 'float'> 15.25

# %% [markdown]
# OPERATORS

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 20
b =30
a = b
print(a)
# Out:
# 30

# %%
a = 20
b =30
b= a
print(b)
# Out:
# 20

# %%
a = 100
b = 200

print(a == b)
# Out:
# False

# %%
a = 100
b = 200

print(a != b)
# Out:
# True

# %%
a = 100
b = 200

print(a < b)
# Out:
# True

# %%
a = 100
b = 200

print(a > b)
# Out:
# False

# %%
a = 100
b = 200
print(a <= b)
# Out:
# True

# %%
a = 200
b = 200
print(a <= b)
# Out:
# True

# %%
a = 100
b = 200

print(a >= b)
# Out:
# False

# %% [markdown]
# Type Conversion

# %%
a =25
b =5 
answer = a / b
print(answer)
print(type(answer))
# Out:
# 5.0
# <class 'float'>

# %% [markdown]
# Type Casting

# %%
marks = 60
marks = float(marks)
print(marks)
print(type(marks))
# Out:
# 60.0
# <class 'float'>

# %%
marks = 60.2 # float
print(marks)
print(type(marks))
marks = int(marks)
print(marks)
print(type(marks))
# Out:
# 60.2
# <class 'float'>
# 60
# <class 'int'>

# %%
name = 'mehmood' # we cant convert string into int
name = int(name)
print(type(name))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 2
#       1 name = 'mehmood' # we cant convert string into int
# ----> 2 name = int(name)
#       3 print(type(name))
#
# ValueError: invalid literal for int() with base 10: 'mehmood'

# %%
ab = "60"
ab = float(ab)
print(type(ab))
# Out:
# <class 'float'>

# %%
# input
